# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## DataFrame

# %%
data = {"İsim": ["Ali", "Ayşe", "Fatma", "Veli"], "boy cm": [170,160,170,180], "kilo-kg": [70, 60, 60, 80]}
df = pd.DataFrame(data, index= ["A", "B", "C", "D"])
df["BMI"] = df["kilo-kg"] / (df["boy cm"] /100) ** 2
df["new"] = np.arange(4)

# %%
df
# Out:
#     İsim  boy cm  kilo-kg        BMI  new
# A    Ali     170       70  24.221453    0
# B   Ayşe     160       60  23.437500    1
# C  Fatma     170       60  20.761246    2
# D   Veli     180       80  24.691358    3

# %% [markdown]
# ## Removing Columns & Rows

# %%
df.drop("new") # axis varsayılan değer 0 - sıfırdır. ve ssatır silmek içindir. Sütun silmek isteniyorsa axis = 1 yapılmalı
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.drop("new") # axis varsayılan değer 0 - sıfırdır. ve ssatır silmek içindir. Sütun silmek isteniyorsa axis = 1 yapılmalı
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
#    5575         errors=errors,
#    5576     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:4785, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4783 for axis, labels in axes.items():
#    4784     if labels is not None:
# -> 4785         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4787 if inplace:
#    4788     self._update_inplace(obj)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:4827, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4825         new_axis = axis.drop(labels, level=level, errors=errors)
#    4826     else:
# -> 4827         new_axis = axis.drop(labels, errors=errors)
#    4828     indexer = axis.get_indexer(new_axis)
#    4830 # Case for non-unique axis
#    4831 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['new'] not found in axis"

# %%
df.drop("İsim", axis= 1)
# Out:
#    boy cm  kilo-kg        BMI  new
# A     170       70  24.221453    0
# B     160       60  23.437500    1
# C     170       60  20.761246    2
# D     180       80  24.691358    3

# %%
df.drop("kilo-kg", axis= 1)
# Out:
#     İsim  boy cm        BMI  new
# A    Ali     170  24.221453    0
# B   Ayşe     160  23.437500    1
# C  Fatma     170  20.761246    2
# D   Veli     180  24.691358    3

# %%
df
# Out:
#     İsim  boy cm  kilo-kg        BMI  new
# A    Ali     170       70  24.221453    0
# B   Ayşe     160       60  23.437500    1
# C  Fatma     170       60  20.761246    2
# D   Veli     180       80  24.691358    3

# %%
df.drop("new", axis=1, inplace=True) # inplace parametresi >> varsayılan False tur. True yapılırsa kalıcı değişikliğe imkan sağlar.

# %%
df
# Out:
#     İsim  boy cm  kilo-kg        BMI
# A    Ali     170       70  24.221453
# B   Ayşe     160       60  23.437500
# C  Fatma     170       60  20.761246
# D   Veli     180       80  24.691358

# %%
df.drop("C")
# Out:
#    İsim  boy cm  kilo-kg        BMI
# A   Ali     170       70  24.221453
# B  Ayşe     160       60  23.437500
# D  Veli     180       80  24.691358

# %%
df.drop(["C", "A"])
# Out:
#    İsim  boy cm  kilo-kg        BMI
# B  Ayşe     160       60  23.437500
# D  Veli     180       80  24.691358

# %%
df.drop(["B", "C"], inplace=True)

# %%
df
# Out:
#    İsim  boy cm  kilo-kg        BMI
# A   Ali     170       70  24.221453
# D  Veli     180       80  24.691358

# %%
df.drop(["boy cm", "kilo-kg"], axis= 1, inplace=True)

# %%
df
# Out:
#    İsim        BMI
# A   Ali  24.221453
# D  Veli  24.691358

# %% [markdown]
# ## Selecting Rows and Columns using .loc[ ] and iloc[ ]

# %%
np.random.seed(45)

data = np.random.randint(1,100, 20).reshape(5, 4)

df = pd.DataFrame(data= data, index= range(101, 106), columns=["col1","col2","col3","col4"])

df
# Out:
#      col1  col2  col3  col4
# 101    76    31     4    33
# 102    96    62    86    36
# 103    69    16    66    15
# 104    54    58    73    88
# 105    47     9    54    13

# %%
df.loc[103]   # buradaki label olan 103. İnteger olan değil. Çünkü kendimiz verdik. Otomatik atanmadı...
# Out:
# col1    69
# col2    16
# col3    66
# col4    15
# Name: 103, dtype: int32

# %%
df.loc[102:104]   # int olsaydı son değeri getirmezdi. Label olduğu için 104 de dahil oldu. Biz oluşturduk...
# Out:
#      col1  col2  col3  col4
# 102    96    62    86    36
# 103    69    16    66    15
# 104    54    58    73    88

# %%
df
# Out:
#      col1  col2  col3  col4
# 101    76    31     4    33
# 102    96    62    86    36
# 103    69    16    66    15
# 104    54    58    73    88
# 105    47     9    54    13

# %%
df.iloc[1:4]  # 4. dahil değil. iloc olduğu için. int değerler ile calıstı..
# Out:
#      col1  col2  col3  col4
# 102    96    62    86    36
# 103    69    16    66    15
# 104    54    58    73    88

# %%
df.loc[101]
# Out:
# col1    76
# col2    31
# col3     4
# col4    33
# Name: 101, dtype: int32

# %%
df.iloc[101]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df.iloc[101]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py:1752, in _iLocIndexer._getitem_axis(self, key, axis)
#    1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
# -> 1752 self._validate_integer(key, axis)
#    1754 return self.obj._ixs(key, axis=axis)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py:1685, in _iLocIndexer._validate_integer(self, key, axis)
#    1683 len_axis = len(self.obj._get_axis(axis))
#    1684 if key >= len_axis or key < -len_axis:
# -> 1685     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %%
df
# Out:
#      col1  col2  col3  col4
# 101    76    31     4    33
# 102    96    62    86    36
# 103    69    16    66    15
# 104    54    58    73    88
# 105    47     9    54    13

# %%
"a b c d e".split()
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
df.index = "a b c d e".split()

# %%
df
# Out:
#    col1  col2  col3  col4
# a    76    31     4    33
# b    96    62    86    36
# c    69    16    66    15
# d    54    58    73    88
# e    47     9    54    13

# %%
df.loc["b": "d"]
# Out:
#    col1  col2  col3  col4
# b    96    62    86    36
# c    69    16    66    15
# d    54    58    73    88

# %%
df.iloc[1:4]
# Out:
#    col1  col2  col3  col4
# b    96    62    86    36
# c    69    16    66    15
# d    54    58    73    88

# %%
df
# Out:
#    col1  col2  col3  col4
# a    76    31     4    33
# b    96    62    86    36
# c    69    16    66    15
# d    54    58    73    88
# e    47     9    54    13

# %%
df.iloc[::2]
# Out:
#    col1  col2  col3  col4
# a    76    31     4    33
# c    69    16    66    15
# e    47     9    54    13

# %%
df.loc["a":"e":2]
# Out:
#    col1  col2  col3  col4
# a    76    31     4    33
# c    69    16    66    15
# e    47     9    54    13

# %%
df
# Out:
#    col1  col2  col3  col4
# a    76    31     4    33
# b    96    62    86    36
# c    69    16    66    15
# d    54    58    73    88
# e    47     9    54    13

# %%
df.loc["a": "c", "col3"]    # virgülun solu satırları, sağı sütunları ifade eder. 
                            # sütun ismi tek başına yazılırsa sonuç pandas serisi olarak gelir.
# Out:
# a     4
# b    86
# c    66
# Name: col3, dtype: int32

# %%
a = df.loc["a": "c", "col3"]
a
# Out:
# a     4
# b    86
# c    66
# Name: col3, dtype: int32

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
b = df.loc["a": "c", ["col3"]]
b
# Out:
#    col3
# a     4
# b    86
# c    66

# %%
type(b)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#    col1  col2  col3  col4
# a    76    31     4    33
# b    96    62    86    36
# c    69    16    66    15
# d    54    58    73    88
# e    47     9    54    13

# %%
df.iloc[:3, 2]
# Out:
# a     4
# b    86
# c    66
# Name: col3, dtype: int32

# %%
df.iloc[:3, [2]]
# Out:
#    col3
# a     4
# b    86
# c    66

# %%
df
# Out:
#    col1  col2  col3  col4
# a    76    31     4    33
# b    96    62    86    36
# c    69    16    66    15
# d    54    58    73    88
# e    47     9    54    13

# %%
df.loc["d":"e", "col2" : "col3"]
# Out:
#    col2  col3
# d    58    73
# e     9    54

# %%
df.loc["d":"e", "col2" : "col4"]
# Out:
#    col2  col3  col4
# d    58    73    88
# e     9    54    13

# %%
df
# Out:
#    col1  col2  col3  col4
# a    76    31     4    33
# b    96    62    86    36
# c    69    16    66    15
# d    54    58    73    88
# e    47     9    54    13

# %%
df.loc["d":"e", ["col2","col4"]]
# Out:
#    col2  col4
# d    58    88
# e     9    13

# %%
df.loc[["d","e"], ["col2","col4"]]
# Out:
#    col2  col4
# d    58    88
# e     9    13

# %%
df
# Out:
#    col1  col2  col3  col4
# a    76    31     4    33
# b    96    62    86    36
# c    69    16    66    15
# d    54    58    73    88
# e    47     9    54    13

# %%
df.loc[["d","a"], ["col2","col4"]]
# Out:
#    col2  col4
# d    58    88
# a    31    33

# %%
df.loc["d":"e"]
# Out:
#    col1  col2  col3  col4
# d    54    58    73    88
# e    47     9    54    13

# %%
df.loc["d":"e"]["col2"]
# Out:
# d    58
# e     9
# Name: col2, dtype: int32

# %%
df.loc["d":"e"][["col2"]]
# Out:
#    col2
# d    58
# e     9

# %%
df
# Out:
#    col1  col2  col3  col4
# a    76    31     4    33
# b    96    62    86    36
# c    69    16    66    15
# d    54    58    73    88
# e    47     9    54    13

# %%
df.loc["d":"e"][["col2","col3"]]
# Out:
#    col2  col3
# d    58    73
# e     9    54

# %%
df[["col3"]]
# Out:
#    col3
# a     4
# b    86
# c    66
# d    73
# e    54

# %%
df
# Out:
#    col1  col2  col3  col4
# a    76    31     4    33
# b    96    62    86    36
# c    69    16    66    15
# d    54    58    73    88
# e    47     9    54    13

# %%
df.loc[["d", "a", "b"] , ["col3", "col1"]]
# Out:
#    col3  col1
# d    73    54
# a     4    76
# b    86    96

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df1 = df.copy()

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.describe().T
# Out:
#           count       mean        std   min      25%      50%   75%       max
# survived  891.0   0.383838   0.486592  0.00   0.0000   0.0000   1.0    1.0000
# pclass    891.0   2.308642   0.836071  1.00   2.0000   3.0000   3.0    3.0000
# age       714.0  29.699118  14.526497  0.42  20.1250  28.0000  38.0   80.0000
# sibsp     891.0   0.523008   1.102743  0.00   0.0000   0.0000   1.0    8.0000
# parch     891.0   0.381594   0.806057  0.00   0.0000   0.0000   0.0    6.0000
# fare      891.0  32.204208  49.693429  0.00   7.9104  14.4542  31.0  512.3292

# %%
df.describe(include="object").T
# Out:
#             count unique          top freq
# sex           891      2         male  577
# embarked      889      3            S  644
# who           891      3          man  537
# embark_town   889      3  Southampton  644
# alive         891      2           no  549

# %%
df.describe(include="all").T
# Out:
#              count unique          top freq       mean        std   min  \
# survived     891.0    NaN          NaN  NaN   0.383838   0.486592   0.0
# pclass       891.0    NaN          NaN  NaN   2.308642   0.836071   1.0
# sex            891      2         male  577        NaN        NaN   NaN
# age          714.0    NaN          NaN  NaN  29.699118  14.526497  0.42
# sibsp        891.0    NaN          NaN  NaN   0.523008   1.102743   0.0
# parch        891.0    NaN          NaN  NaN   0.381594   0.806057   0.0
# fare         891.0    NaN          NaN  NaN  32.204208  49.693429   0.0
# embarked       889      3            S  644        NaN        NaN   NaN
# class          891      3        Third  491        NaN        NaN   NaN
# who            891      3          man  537        NaN        NaN   NaN
# adult_male     891      2         True  537        NaN        NaN   NaN
# deck           203      7            C   59        NaN        NaN   NaN
# embark_town    889      3  Southampton  644        NaN        NaN   NaN
# alive          891      2           no  549        NaN        NaN   NaN
# alone          891      2         True  537        NaN        NaN   NaN
#
#                 25%      50%   75%       max
# survived        0.0      0.0   1.0       1.0
# pclass          2.0      3.0   3.0       3.0
# sex             NaN      NaN   NaN       NaN
# age          20.125     28.0  38.0      80.0
# sibsp           0.0      0.0   1.0       8.0
# parch           0.0      0.0   0.0       6.0
# fare         7.9104  14.4542  31.0  512.3292
# embarked        NaN      NaN   NaN       NaN
# class           NaN      NaN   NaN       NaN
# who             NaN      NaN   NaN       NaN
# adult_male      NaN      NaN   NaN       NaN
# deck            NaN      NaN   NaN       NaN
# embark_town     NaN      NaN   NaN       NaN
# alive           NaN      NaN   NaN       NaN
# alone           NaN      NaN   NaN       NaN

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.survived.value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df.survived.value_counts(normalize=True)
# Out:
# survived
# 0    0.616162
# 1    0.383838
# Name: proportion, dtype: float64

# %%
df.survived.value_counts(normalize=True) * 100
# Out:
# survived
# 0    61.616162
# 1    38.383838
# Name: proportion, dtype: float64

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.drop("alive")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 df.drop("alive")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
#    5575         errors=errors,
#    5576     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:4785, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4783 for axis, labels in axes.items():
#    4784     if labels is not None:
# -> 4785         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4787 if inplace:
#    4788     self._update_inplace(obj)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:4827, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4825         new_axis = axis.drop(labels, level=level, errors=errors)
#    4826     else:
# -> 4827         new_axis = axis.drop(labels, errors=errors)
#    4828     indexer = axis.get_indexer(new_axis)
#    4830 # Case for non-unique axis
#    4831 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['alive'] not found in axis"

# %%
df.drop("alive", axis= 0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 df.drop("alive", axis= 0)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
#    5575         errors=errors,
#    5576     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:4785, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4783 for axis, labels in axes.items():
#    4784     if labels is not None:
# -> 4785         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4787 if inplace:
#    4788     self._update_inplace(obj)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:4827, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4825         new_axis = axis.drop(labels, level=level, errors=errors)
#    4826     else:
# -> 4827         new_axis = axis.drop(labels, errors=errors)
#    4828     indexer = axis.get_indexer(new_axis)
#    4830 # Case for non-unique axis
#    4831 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['alive'] not found in axis"

# %%
df.drop("alive", axis= 1)   # inplace True yapmadığım taktirde kalıcı silme yapmaz.
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town  alone
# 0      man        True  NaN  Southampton  False
# 1    woman       False    C    Cherbourg  False
# 2    woman       False  NaN  Southampton   True
# 3    woman       False    C  Southampton  False
# 4      man        True  NaN  Southampton   True
# ..     ...         ...  ...          ...    ...
# 886    man        True  NaN  Southampton   True
# 887  woman       False    B  Southampton   True
# 888  woman       False  NaN  Southampton  False
# 889    man        True    C    Cherbourg   True
# 890    man        True  NaN   Queenstown   True
#
# [891 rows x 14 columns]

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df.drop("alive", axis= 1, inplace=True)

# %%
df   # alive silindi...
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town  alone
# 0      man        True  NaN  Southampton  False
# 1    woman       False    C    Cherbourg  False
# 2    woman       False  NaN  Southampton   True
# 3    woman       False    C  Southampton  False
# 4      man        True  NaN  Southampton   True
# ..     ...         ...  ...          ...    ...
# 886    man        True  NaN  Southampton   True
# 887  woman       False    B  Southampton   True
# 888  woman       False  NaN  Southampton  False
# 889    man        True    C    Cherbourg   True
# 890    man        True  NaN   Queenstown   True
#
# [891 rows x 14 columns]

# %%
df.iloc[:100]   # 100 dahil değil.
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# ..       ...     ...     ...   ...    ...    ...      ...      ...     ...
# 95         0       3    male   NaN      0      0   8.0500        S   Third
# 96         0       1    male  71.0      0      0  34.6542        C   First
# 97         1       1    male  23.0      0      1  63.3583        C   First
# 98         1       2  female  34.0      0      1  23.0000        S  Second
# 99         0       2    male  34.0      1      0  26.0000        S  Second
#
#       who  adult_male deck  embark_town  alone
# 0     man        True  NaN  Southampton  False
# 1   woman       False    C    Cherbourg  False
# 2   woman       False  NaN  Southampton   True
# 3   woman       False    C  Southampton  False
# 4     man        True  NaN  Southampton   True
# ..    ...         ...  ...          ...    ...
# 95    man        True  NaN  Southampton   True
# 96    man        True    A    Cherbourg   True
# 97    man        True    D    Cherbourg  False
# 98  woman       False  NaN  Southampton  False
# 99    man        True  NaN  Southampton  False
#
# [100 rows x 14 columns]

# %%
df.iloc[:100:2]
# Out:
#     survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 0          0       3    male  22.00      1      0    7.2500        S   Third
# 2          1       3  female  26.00      0      0    7.9250        S   Third
# 4          0       3    male  35.00      0      0    8.0500        S   Third
# 6          0       1    male  54.00      0      0   51.8625        S   First
# 8          1       3  female  27.00      0      2   11.1333        S   Third
# 10         1       3  female   4.00      1      1   16.7000        S   Third
# 12         0       3    male  20.00      0      0    8.0500        S   Third
# 14         0       3  female  14.00      0      0    7.8542        S   Third
# 16         0       3    male   2.00      4      1   29.1250        Q   Third
# 18         0       3  female  31.00      1      0   18.0000        S   Third
# 20         0       2    male  35.00      0      0   26.0000        S  Second
# 22         1       3  female  15.00      0      0    8.0292        Q   Third
# 24         0       3  female   8.00      3      1   21.0750        S   Third
# 26         0       3    male    NaN      0      0    7.2250        C   Third
# 28         1       3  female    NaN      0      0    7.8792        Q   Third
# 30         0       1    male  40.00      0      0   27.7208        C   First
# 32         1       3  female    NaN      0      0    7.7500        Q   Third
# 34         0       1    male  28.00      1      0   82.1708        C   First
# 36         1       3    male    NaN      0      0    7.2292        C   Third
# 38         0       3  female  18.00      2      0   18.0000        S   Third
# 40         0       3  female  40.00      1      0    9.4750        S   Third
# 42         0       3    male    NaN      0      0    7.8958        C   Third
# 44         1       3  female  19.00      0      0    7.8792        Q   Third
# 46         0       3    male    NaN      1      0   15.5000        Q   Third
# 48         0       3    male    NaN      2      0   21.6792        C   Third
# 50         0       3    male   7.00      4      1   39.6875        S   Third
# 52         1       1  female  49.00      1      0   76.7292        C   First
# 54         0       1    male  65.00      0      1   61.9792        C   First
# 56         1       2  female  21.00      0      0   10.5000        S  Second
# 58         1       2  female   5.00      1      2   27.7500        S  Second
# 60         0       3    male  22.00      0      0    7.2292        C   Third
# 62         0       1    male  45.00      1      0   83.4750        S   First
# 64         0       1    male    NaN      0      0   27.7208        C   First
# 66         1       2  female  29.00      0      0   10.5000        S  Second
# 68         1       3  female  17.00      4      2    7.9250        S   Third
# 70         0       2    male  32.00      0      0   10.5000        S  Second
# 72         0       2    male  21.00      0      0   73.5000        S  Second
# 74         1       3    male  32.00      0      0   56.4958        S   Third
# 76         0       3    male    NaN      0      0    7.8958        S   Third
# 78         1       2    male   0.83      0      2   29.0000        S  Second
# 80         0       3    male  22.00      0      0    9.0000        S   Third
# 82         1       3  female    NaN      0      0    7.7875        Q   Third
# 84         1       2  female  17.00      0      0   10.5000        S  Second
# 86         0       3    male  16.00      1      3   34.3750        S   Third
# 88         1       1  female  23.00      3      2  263.0000        S   First
# 90         0       3    male  29.00      0      0    8.0500        S   Third
# 92         0       1    male  46.00      1      0   61.1750        S   First
# 94         0       3    male  59.00      0      0    7.2500        S   Third
# 96         0       1    male  71.00      0      0   34.6542        C   First
# 98         1       2  female  34.00      0      1   23.0000        S  Second
#
#       who  adult_male deck  embark_town  alone
# 0     man        True  NaN  Southampton  False
# 2   woman       False  NaN  Southampton   True
# 4     man        True  NaN  Southampton   True
# 6     man        True    E  Southampton   True
# 8   woman       False  NaN  Southampton  False
# 10  child       False    G  Southampton  False
# 12    man        True  NaN  Southampton   True
# 14  child       False  NaN  Southampton   True
# 16  child       False  NaN   Queenstown  False
# 18  woman       False  NaN  Southampton  False
# 20    man        True  NaN  Southampton   True
# 22  child       False  NaN   Queenstown   True
# 24  child       False  NaN  Southampton  False
# 26    man        True  NaN    Cherbourg   True
# 28  woman       False  NaN   Queenstown   True
# 30    man        True  NaN    Cherbourg   True
# 32  woman       False  NaN   Queenstown   True
# 34    man        True  NaN    Cherbourg  False
# 36    man        True  NaN    Cherbourg   True
# 38  woman       False  NaN  Southampton  False
# 40  woman       False  NaN  Southampton  False
# 42    man        True  NaN    Cherbourg   True
# 44  woman       False  NaN   Queenstown   True
# 46    man        True  NaN   Queenstown  False
# 48    man        True  NaN    Cherbourg  False
# 50  child       False  NaN  Southampton  False
# 52  woman       False    D    Cherbourg  False
# 54    man        True    B    Cherbourg  False
# 56  woman       False  NaN  Southampton   True
# 58  child       False  NaN  Southampton  False
# 60    man        True  NaN    Cherbourg   True
# 62    man        True    C  Southampton  False
# 64    man        True  NaN    Cherbourg   True
# 66  woman       False    F  Southampton   True
# 68  woman       False  NaN  Southampton  False
# 70    man        True  NaN  Southampton   True
# 72    man        True  NaN  Southampton   True
# 74    man        True  NaN  Southampton   True
# 76    man        True  NaN  Southampton   True
# 78  child       False  NaN  Southampton  False
# 80    man        True  NaN  Southampton   True
# 82  woman       False  NaN   Queenstown   True
# 84  woman       False  NaN  Southampton   True
# 86    man        True  NaN  Southampton  False
# 88  woman       False    C  Southampton  False
# 90    man        True  NaN  Southampton   True
# 92    man        True    E  Southampton  False
# 94    man        True  NaN  Southampton   True
# 96    man        True    A    Cherbourg   True
# 98  woman       False  NaN  Southampton  False
