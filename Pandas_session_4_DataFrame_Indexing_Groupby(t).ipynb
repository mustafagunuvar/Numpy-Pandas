# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# # DataFrame

# %% [markdown]
# ## Conditional Selection

# %%
np.random.seed(45)

data = np.random.randint(1, 100, 20).reshape(5,4)

df = pd.DataFrame(data= data, index= range(101, 106), columns= ["col1", "col2", "col3", "col4"])

df
# Out:
#      col1  col2  col3  col4
# 101    76    31     4    33
# 102    96    62    86    36
# 103    69    16    66    15
# 104    54    58    73    88
# 105    47     9    54    13

# %%
df.index = "a b c d e".split()
df
# Out:
#    col1  col2  col3  col4
# a    76    31     4    33
# b    96    62    86    36
# c    69    16    66    15
# d    54    58    73    88
# e    47     9    54    13

# %%
df > 50
# Out:
#     col1   col2   col3   col4
# a   True  False  False  False
# b   True   True   True  False
# c   True  False   True  False
# d   True   True   True   True
# e  False  False   True  False

# %%
(df > 50).sum()
# Out:
# col1    4
# col2    2
# col3    4
# col4    1
# dtype: int64

# %%
df[df > 50]
# Out:
#    col1  col2  col3  col4
# a  76.0   NaN   NaN   NaN
# b  96.0  62.0  86.0   NaN
# c  69.0   NaN  66.0   NaN
# d  54.0  58.0  73.0  88.0
# e   NaN   NaN  54.0   NaN

# %%
df
# Out:
#    col1  col2  col3  col4
# a    76    31     4    33
# b    96    62    86    36
# c    69    16    66    15
# d    54    58    73    88
# e    47     9    54    13

# %%
df.col2
# Out:
# a    31
# b    62
# c    16
# d    58
# e     9
# Name: col2, dtype: int32

# %%
df.col2 > 50
# Out:
# a    False
# b     True
# c    False
# d     True
# e    False
# Name: col2, dtype: bool

# %%
df[df.col2 > 50]    # col 2 50den büyük olan value ların tüm satırını getirir.
# Out:
#    col1  col2  col3  col4
# b    96    62    86    36
# d    54    58    73    88

# %%
titanic = sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic["age"] > 50
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: age, Length: 891, dtype: bool

# %%
titanic[titanic["age"] > 50]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 11          1       1  female  58.0      0      0  26.5500        S   First
# 15          1       2  female  55.0      0      0  16.0000        S  Second
# 33          0       2    male  66.0      0      0  10.5000        S  Second
# 54          0       1    male  65.0      0      1  61.9792        C   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 820         1       1  female  52.0      1      1  93.5000        S   First
# 829         1       1  female  62.0      0      0  80.0000      NaN   First
# 851         0       3    male  74.0      0      0   7.7750        S   Third
# 857         1       1    male  51.0      0      0  26.5500        S   First
# 879         1       1  female  56.0      0      1  83.1583        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
(titanic["age"] > 50) & (titanic["survived"] == 1)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
titanic[(titanic["age"] > 50) & (titanic["survived"] == 1)]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 11          1       1  female  58.0      0      0   26.5500        S   First
# 15          1       2  female  55.0      0      0   16.0000        S  Second
# 195         1       1  female  58.0      0      0  146.5208        C   First
# 268         1       1  female  58.0      0      1  153.4625        S   First
# 275         1       1  female  63.0      1      0   77.9583        S   First
# 366         1       1  female  60.0      1      0   75.2500        C   First
# 449         1       1    male  52.0      0      0   30.5000        S   First
# 483         1       3  female  63.0      0      0    9.5875        S   Third
# 496         1       1  female  54.0      1      0   78.2667        C   First
# 513         1       1  female  54.0      1      0   59.4000        C   First
# 570         1       2    male  62.0      0      0   10.5000        S  Second
# ...

# %%
titanic[(titanic["age"] > 50) & (titanic["survived"] == 1)].shape
# Out:
# (22, 15)

# %%
titanic[(titanic.age > 50) | (titanic.survived == 1)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic[(titanic.age > 50) | (titanic.survived == 1)].shape
# Out:
# (384, 15)

# %% [markdown]
# ## Reset Index & Set Index

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.set_index("pclass")   # pclass feature dan aldı. İndex olarak atadı. Feature da yok.
# Out:
#         survived     sex   age  sibsp  parch     fare embarked   class    who  \
# pclass
# 3              0    male  22.0      1      0   7.2500        S   Third    man
# 1              1  female  38.0      1      0  71.2833        C   First  woman
# 3              1  female  26.0      0      0   7.9250        S   Third  woman
# 1              1  female  35.0      1      0  53.1000        S   First  woman
# 3              0    male  35.0      0      0   8.0500        S   Third    man
# ...          ...     ...   ...    ...    ...      ...      ...     ...    ...
# 2              0    male  27.0      0      0  13.0000        S  Second    man
# 1              1  female  19.0      0      0  30.0000        S   First  woman
# 3              0  female   NaN      1      2  23.4500        S   Third  woman
# 1              1    male  26.0      0      0  30.0000        C   First    man
# 3              0    male  32.0      0      0   7.7500        Q   Third    man
#
# ...

# %%
titanic.set_index("pclass", drop= False)  # drop parametresinin default degeri True dur. Eğer false yaparsan Featureda da kalır.
# Out:
#         survived  pclass     sex   age  sibsp  parch     fare embarked  \
# pclass
# 3              0       3    male  22.0      1      0   7.2500        S
# 1              1       1  female  38.0      1      0  71.2833        C
# 3              1       3  female  26.0      0      0   7.9250        S
# 1              1       1  female  35.0      1      0  53.1000        S
# 3              0       3    male  35.0      0      0   8.0500        S
# ...          ...     ...     ...   ...    ...    ...      ...      ...
# 2              0       2    male  27.0      0      0  13.0000        S
# 1              1       1  female  19.0      0      0  30.0000        S
# 3              0       3  female   NaN      1      2  23.4500        S
# 1              1       1    male  26.0      0      0  30.0000        C
# 3              0       3    male  32.0      0      0   7.7500        Q
#
#          class    who  adult_male deck  embark_town alive  alone
# pclass
# ...

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.set_index("pclass", inplace=True)

# %%
titanic
# Out:
#         survived     sex   age  sibsp  parch     fare embarked   class    who  \
# pclass
# 3              0    male  22.0      1      0   7.2500        S   Third    man
# 1              1  female  38.0      1      0  71.2833        C   First  woman
# 3              1  female  26.0      0      0   7.9250        S   Third  woman
# 1              1  female  35.0      1      0  53.1000        S   First  woman
# 3              0    male  35.0      0      0   8.0500        S   Third    man
# ...          ...     ...   ...    ...    ...      ...      ...     ...    ...
# 2              0    male  27.0      0      0  13.0000        S  Second    man
# 1              1  female  19.0      0      0  30.0000        S   First  woman
# 3              0  female   NaN      1      2  23.4500        S   Third  woman
# 1              1    male  26.0      0      0  30.0000        C   First    man
# 3              0    male  32.0      0      0   7.7500        Q   Third    man
#
# ...

# %%
titanic.reset_index()
# Out:
#      pclass  survived     sex   age  sibsp  parch     fare embarked   class  \
# 0         3         0    male  22.0      1      0   7.2500        S   Third
# 1         1         1  female  38.0      1      0  71.2833        C   First
# 2         3         1  female  26.0      0      0   7.9250        S   Third
# 3         1         1  female  35.0      1      0  53.1000        S   First
# 4         3         0    male  35.0      0      0   8.0500        S   Third
# ..      ...       ...     ...   ...    ...    ...      ...      ...     ...
# 886       2         0    male  27.0      0      0  13.0000        S  Second
# 887       1         1  female  19.0      0      0  30.0000        S   First
# 888       3         0  female   NaN      1      2  23.4500        S   Third
# 889       1         1    male  26.0      0      0  30.0000        C   First
# 890       3         0    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.reset_index(drop= True)
# Out:
#      survived     sex   age  sibsp  parch     fare embarked   class    who  \
# 0           0    male  22.0      1      0   7.2500        S   Third    man
# 1           1  female  38.0      1      0  71.2833        C   First  woman
# 2           1  female  26.0      0      0   7.9250        S   Third  woman
# 3           1  female  35.0      1      0  53.1000        S   First  woman
# 4           0    male  35.0      0      0   8.0500        S   Third    man
# ..        ...     ...   ...    ...    ...      ...      ...     ...    ...
# 886         0    male  27.0      0      0  13.0000        S  Second    man
# 887         1  female  19.0      0      0  30.0000        S   First  woman
# 888         0  female   NaN      1      2  23.4500        S   Third  woman
# 889         1    male  26.0      0      0  30.0000        C   First    man
# 890         0    male  32.0      0      0   7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive  alone
# ...

# %%
titanic.reset_index(drop= True, inplace=True)   # pclass temelli gitti.

# %%
titanic
# Out:
#      survived     sex   age  sibsp  parch     fare embarked   class    who  \
# 0           0    male  22.0      1      0   7.2500        S   Third    man
# 1           1  female  38.0      1      0  71.2833        C   First  woman
# 2           1  female  26.0      0      0   7.9250        S   Third  woman
# 3           1  female  35.0      1      0  53.1000        S   First  woman
# 4           0    male  35.0      0      0   8.0500        S   Third    man
# ..        ...     ...   ...    ...    ...      ...      ...     ...    ...
# 886         0    male  27.0      0      0  13.0000        S  Second    man
# 887         1  female  19.0      0      0  30.0000        S   First  woman
# 888         0  female   NaN      1      2  23.4500        S   Third  woman
# 889         1    male  26.0      0      0  30.0000        C   First    man
# 890         0    male  32.0      0      0   7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive  alone
# ...

# %%
titanic = sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic.dropna()   # içinde nan olan bütün satırları siler...
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.drop([3,100,150,142,888])   # içerisine belirttiğin index numaralarını siler.
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.drop([3,100,150,142,888], inplace=True)

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.reset_index()
# Out:
#      index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0        0         0       3    male  22.0      1      0   7.2500        S
# 1        1         1       1  female  38.0      1      0  71.2833        C
# 2        2         1       3  female  26.0      0      0   7.9250        S
# 3        4         0       3    male  35.0      0      0   8.0500        S
# 4        5         0       3    male   NaN      0      0   8.4583        Q
# ..     ...       ...     ...     ...   ...    ...    ...      ...      ...
# 881    885         0       3  female  39.0      0      5  29.1250        Q
# 882    886         0       2    male  27.0      0      0  13.0000        S
# 883    887         1       1  female  19.0      0      0  30.0000        S
# 884    889         1       1    male  26.0      0      0  30.0000        C
# 885    890         0       3    male  32.0      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.reset_index(drop= True)  # drop= True index label ın sütun olarak kalmasını engeller.
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           0       3    male  35.0      0      0   8.0500        S   Third
# 4           0       3    male   NaN      0      0   8.4583        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 881         0       3  female  39.0      0      5  29.1250        Q   Third
# 882         0       2    male  27.0      0      0  13.0000        S  Second
# 883         1       1  female  19.0      0      0  30.0000        S   First
# 884         1       1    male  26.0      0      0  30.0000        C   First
# 885         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## Groupby Aggregation Methods(aggregate() & agg())

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True

# %%
titanic.groupby("sex")["age"].mean()
# Out:
# sex
# female    27.903101
# male      30.681792
# Name: age, dtype: float64

# %%
titanic.groupby("pclass")["fare"].mean()
# Out:
# pclass
# 1    84.299128
# 2    20.706649
# 3    13.662908
# Name: fare, dtype: float64

# %%
titanic.groupby("sex")["age"].min()   # 0.75 şeklinde yaş olamayacagı için bir yanlışlık olmalı...
# Out:
# sex
# female    0.75
# male      0.42
# Name: age, dtype: float64

# %%
titanic.groupby("sex")["age"].max()   # bu olabilir.
# Out:
# sex
# female    63.0
# male      80.0
# Name: age, dtype: float64

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
titanic.groupby("sex")["age"].agg([min, max, np.mean])
# Out:
#          min   max       mean
# sex
# female  0.75  63.0  27.903101
# male    0.42  80.0  30.681792

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.groupby("sex")["survived"].count()
# Out:
# sex
# female    310
# male      576
# Name: survived, dtype: int64

# %%
titanic.groupby(["sex", "survived"]).count()
# Out:
#                  pclass  age  sibsp  parch  fare  embarked  class  who  \
# sex    survived
# female 0             79   63     79     79    79        79     79   79
#        1            231  195    231    231   231       229    231  231
# male   0            467  359    467    467   467       467    467  467
#        1            109   93    109    109   109       109    109  109
#
#                  adult_male  deck  embark_town  alive  alone
# sex    survived
# female 0                 79     6           79     79     79
#        1                231    90          229    231    231
# male   0                467    61          467    467    467
#        1                109    45          109    109    109

# %%
titanic.groupby(["sex", "survived"]).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# ...

# %%
pip install --upgrade pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
titanic.groupby(["survived", "sex"])["survived"].count()  # önce cinsiyet sonra hayatta kalanlara göre gruplama yaptı..
# Out:
# survived  sex
# 0         female     79
#           male      467
# 1         female    231
#           male      109
# Name: survived, dtype: int64

# %%
titanic.groupby(["survived", "sex"])[["survived"]].count()
# Out:
#                  survived
# survived sex
# 0        female        79
#          male         467
# 1        female       231
#          male         109

# %%
titanic.groupby(["survived", "pclass", "sex"])[["survived"]].count()
# Out:
#                         survived
# survived pclass sex
# 0        1      female         3
#                 male          77
#          2      female         6
#                 male          90
#          3      female        70
#                 male         300
# 1        1      female        90
#                 male          45
#          2      female        70
#                 male          17
#          3      female        71
#                 male          47

# %%
titanic.groupby(["pclass", "sex"])[["survived"]].value_counts(normalize=True) * 100
# Out:
# pclass  sex     survived
# 1       female  1           96.774194
#                 0            3.225806
#         male    0           63.114754
#                 1           36.885246
# 2       female  1           92.105263
#                 0            7.894737
#         male    0           84.112150
#                 1           15.887850
# 3       female  1           50.354610
#                 0           49.645390
#         male    0           86.455331
#                 1           13.544669
# Name: proportion, dtype: float64
